# %%
using JLD2
using Plots
using LaTeXStrings
using LinearAlgebra
using Polynomials
using Printf

# %%
# ------------------------------------------------------------
# Load data
# ------------------------------------------------------------
@load "./data/gamma_scan_2Delta3.jld2" gamma_list kappa_matrix_list

# ------------------------------------------------------------
# Extract the spectral norm of the kappa matrices
# ------------------------------------------------------------
kappa_2Delta3 = [0.5 * gamma_list[i]^2 * opnorm(kappa_matrix_list[i]) for i in eachindex(gamma_list)]

p1 = plot(
    gamma_list, kappa_2Delta3,
    marker = :circle,
    xscale = :log10,
    yscale = :log10,
    xlabel = L"\gamma",
    title = L"\mathrm{Double-}\Delta_3: \frac{\gamma^2}{2}\,\|\kappa\| \mathrm{v.s.}\; \gamma",
    label = "numerical result",
    legend = :bottomright
)

# top-left formula (like your current style)
annotate!(
    (0.00001, 1.05),
    text(L"\frac{\gamma^2}{2}\,\|\kappa \|", 12)
);

p = fit(log10.(gamma_list[end-20:end]), log10.(kappa_2Delta3[end-20:end]), 1) 
a, b = coeffs(p)
fit_curve = 10 .^ (a .+ b .* log10.(gamma_list))
# ------------------------------------------------------------
# Show plots
# ------------------------------------------------------------
plot!(
    p1,
    gamma_list,
    fit_curve,
    lw = 2,
    linestyle = :dash,
    label = "power-law fit (slope = $(round(b, digits=6)))"
)

display(p1)

# %%
# ------------------------------------------------------------
# Load data
# ------------------------------------------------------------
@load "./data/gamma_scan_15move.jld2" gamma_list kappa_matrix_list

# ------------------------------------------------------------
# Extract the spectral norm of the kappa matrices
# ------------------------------------------------------------
kappa_15move = [0.5 * gamma_list[i]^2 * opnorm(kappa_matrix_list[i]) for i in eachindex(gamma_list)]

p2 = plot(
    gamma_list, kappa_15move,
    marker = :circle,
    xscale = :log10,
    yscale = :log10,
    xlabel = L"\gamma",
    title = L"\mathrm{1-5\ move:}\ \frac{\gamma^2}{2}\,\|\kappa\| \ \mathrm{vs.}\ \gamma",
    label = "numerical result",
    legend = :bottomright
)

# top-left formula (like your current style)
annotate!(
    (0.00001, 1.05),
    text(L"\frac{\gamma^2}{2}\,\|\kappa \|", 12)
)

p = fit(log10.(gamma_list[end-20:end]), log10.(kappa_15move[end-20:end]), 1) 
a, b = coeffs(p)
fit_curve = 10 .^ (a .+ b .* log10.(gamma_list))
# ------------------------------------------------------------
# Show plots
# ------------------------------------------------------------
plot!(
    p2,
    gamma_list,
    fit_curve,
    lw = 2,
    linestyle = :dash,
    label = "power-law fit (slope = $(round(b, digits=6)))"
)

display(p2)
# Out:
# 2-element Vector{Symbol}:
#  :gamma_list
#  :kappa_matrix_list

# %%
kappa_matrix_list[4]
# Out:
# 10×10 Matrix{Complex{BigFloat}}:
#    -2.2839-0.0820531im     2.04731-0.00835146im  …  0.0722917-0.184939im
#    2.04731-0.00835146im   -4.87104+0.158507im        -5.04007+0.0761529im
#   0.621239+0.221341im      5.96792-0.225002im         11.9775+0.159923im
#   -1.79986-0.0589042im     3.34167-0.0489615im        2.69863-0.0292799im
#    1.55351+0.0532515im   -0.332085+0.121306im         3.03152+0.120121im
#   0.674773+0.265259im      1.26618-0.201708im    …    4.20778-0.0903205im
#   0.869668+0.14605im       2.04229-0.17845im          4.77761+0.0918118im
#    3.45718-0.0747141im    -8.61149+0.339161im        -9.24821+0.166624im
#   -4.54813-0.211484im      3.32264-0.0733517im       -2.42202-0.302708im
#  0.0722917-0.184939im     -5.04007+0.0761529im       -10.3586-0.0332788im

# %%
precision(real(kappa_matrix_list[4][1]))
# Out:
# 256

# %%
using DoubleFloats
# ------------------------------------------------------------
# Load data
# ------------------------------------------------------------
@load "./data/gamma_scan_B2Wholes.jld2" gamma_list kappa_matrix_list

# ------------------------------------------------------------
# Extract the spectral norm of the kappa matrices
# ------------------------------------------------------------
kappa_B2Wholes =  [0.5 * gamma_list[i]^2 * opnorm(kappa_matrix_list[i]) for i in eachindex(gamma_list)]

p3 = plot(
    gamma_list, kappa_B2Wholes,
    marker = :circle,
    xscale = :log10,
    yscale = :log10,
    xlabel = L"\gamma",
    title = L"\mathrm{B2W holes}\ \frac{\gamma^2}{2}\,\|\kappa\| \ \mathrm{vs.}\ \gamma",
    label = "numerical result",
    legend = :bottomright
)

# top-left formula (like your current style)
annotate!(
    (0.00001, 1.05),
    text(L"\frac{\gamma^2}{2}\,\|\kappa \|", 12)
)

p = fit(log10.(gamma_list), log10.(kappa_B2Wholes), 1) 
a, b = coeffs(p)
fit_curve = 10 .^ (a .+ b .* log10.(gamma_list))
# ------------------------------------------------------------
# Show plots
# ------------------------------------------------------------
plot!(
    p3,
    gamma_list,
    fit_curve,
    lw = 2,
    linestyle = :dash,
    label = "power-law fit (slope = $(round(b, digits=6)))"
)

display(p3)

# %%
gamma_list
# Out:
# 40-element Vector{Double64}:
#  1.0
#  7.01703828670382793298722652496713746e-01
#  4.92388263170673929015505955085519393e-01
#  3.45510729459221932581843752298597422e-01
#  2.42446201708232847923790144627019339e-01
#  1.70125427985258890429296076900982545e-01
#  1.19377664171443650609168157405771658e-01
#  8.37677640068291898834770657749815811e-02
#  5.8780160722749128306661083050365746e-02
#  4.12462638290135183523116646728844237e-02
#  2.89426612471675088503954979543763751e-02
#  2.03091762090473572099212466886010032e-02
#  1.42510267030299810641022685627692198e-02
#  ⋮
#  4.92388263170673929015505955085475446e-05
#  3.45510729459221932581843752298578639e-05
#  2.42446201708232847923790144627003198e-05
#  1.701254279852588904292960769009829e-05
#  1.19377664171443650609168157405773241e-05
#  8.37677640068291898834770657749873619e-06
#  5.87801607227491283066610830503691495e-06
#  4.12462638290135183523116646728882895e-06
#  2.89426612471675088503954979543750375e-06
#  2.03091762090473572099212466886042312e-06
#  1.42510267030299810641022685627702754e-06
#  9.99999999999999999999999999999999379e-07

# %%
gamma_list
# Out:
# 80-element Vector{Float64}:
#  1.0
#  0.8395578619995111
#  0.7048574036451902
#  0.5917685748188823
#  0.49682395947343855
#  0.4171124612056518
#  0.3501900461431711
#  0.29400480643347093
#  0.24683404670686493
#  0.207231464521903
#  0.1739828052930364
#  0.1460686320364989
#  0.12263306841775631
#  ⋮
#  6.846096838574658e-6
#  5.747694424835347e-6
#  4.825522042741279e-6
#  4.051304969235378e-6
#  3.401304938279253e-6
#  2.8555923019901063e-6
#  2.3974349678010785e-6
#  2.0127853758499383e-6
#  1.6898497868124586e-6
#  1.4187266741165963e-6
#  1.191103133283008e-6
#  1.0e-6
