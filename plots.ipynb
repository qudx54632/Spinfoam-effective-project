# %%
using JLD2
using Plots
using LaTeXStrings
using LinearAlgebra
using Polynomials
using Printf

# %%
# ------------------------------------------------------------
# Load data
# ------------------------------------------------------------
@load "./data/gamma_scan_2Delta3.jld2" gamma_list kappa_matrix_list

# ------------------------------------------------------------
# Extract the spectral norm of the kappa matrices
# ------------------------------------------------------------
kappa_2Delta3 = [0.5 * gamma_list[i]^2 * opnorm(kappa_matrix_list[i]) for i in eachindex(gamma_list)]

p1 = plot(
    gamma_list, kappa_2Delta3,
    marker = :circle,
    xscale = :log10,
    yscale = :log10,
    xlabel = L"\gamma",
    title = L"\mathrm{Double-}\Delta_3: \frac{\gamma^2}{2}\,\|\kappa\| \mathrm{v.s.}\; \gamma",
    label = "numerical result",
    legend = :bottomright
)

# top-left formula (like your current style)
annotate!(
    (0.00001, 1.05),
    text(L"\frac{\gamma^2}{2}\,\|\kappa \|", 12)
);

p = fit(log10.(gamma_list[end-20:end]), log10.(kappa_2Delta3[end-20:end]), 1) 
a, b = coeffs(p)
fit_curve = 10 .^ (a .+ b .* log10.(gamma_list))
# ------------------------------------------------------------
# Show plots
# ------------------------------------------------------------
plot!(
    p1,
    gamma_list,
    fit_curve,
    lw = 2,
    linestyle = :dash,
    label = "power-law fit (slope = $(round(b, digits=6)))"
)

display(p1)

# %%
# ------------------------------------------------------------
# Load data
# ------------------------------------------------------------
@load "./data/gamma_scan_15move.jld2" gamma_list kappa_matrix_list

# ------------------------------------------------------------
# Extract the spectral norm of the kappa matrices
# ------------------------------------------------------------
kappa_15move = [0.5 * gamma_list[i]^2 * opnorm(kappa_matrix_list[i]) for i in eachindex(gamma_list)]

p2 = plot(
    gamma_list, kappa_15move,
    marker = :circle,
    xscale = :log10,
    yscale = :log10,
    xlabel = L"\gamma",
    title = L"\mathrm{1-5\ move:}\ \frac{\gamma^2}{2}\,\|\kappa\| \ \mathrm{vs.}\ \gamma",
    label = "numerical result",
    legend = :bottomright
)

# top-left formula (like your current style)
annotate!(
    (0.00001, 1.05),
    text(L"\frac{\gamma^2}{2}\,\|\kappa \|", 12)
)

p = fit(log10.(gamma_list[end-20:end]), log10.(kappa_15move[end-20:end]), 1) 
a, b = coeffs(p)
fit_curve = 10 .^ (a .+ b .* log10.(gamma_list))
# ------------------------------------------------------------
# Show plots
# ------------------------------------------------------------
plot!(
    p2,
    gamma_list,
    fit_curve,
    lw = 2,
    linestyle = :dash,
    label = "power-law fit (slope = $(round(b, digits=6)))"
)

display(p2)

# %%
# ------------------------------------------------------------
# Load data
# ------------------------------------------------------------
@load "./data/gamma_scan_B2Wholes.jld2" gamma_list kappa_matrix_list

# ------------------------------------------------------------
# Extract the spectral norm of the kappa matrices
# ------------------------------------------------------------
kappa_B2Wholes = [0.5 * gamma_list[i]^2 * opnorm(kappa_matrix_list[i]) for i in eachindex(gamma_list)]

p3 = plot(
    gamma_list, kappa_B2Wholes,
    marker = :circle,
    xscale = :log10,
    yscale = :log10,
    xlabel = L"\gamma",
    title = L"\mathrm{B2W holes:}\ \frac{\gamma^2}{2}\,\|\kappa\| \ \mathrm{vs.}\ \gamma",
    label = "numerical result",
    legend = :bottomright
)

# top-left formula (like your current style)
annotate!(
    (0.00001, 1.05),
    text(L"\frac{\gamma^2}{2}\,\|\kappa \|", 12)
)

p = fit(log10.(gamma_list[end-20:end]), log10.(kappa_B2Wholes[end-20:end]), 1) 
a, b = coeffs(p)
fit_curve = 10 .^ (a .+ b .* log10.(gamma_list))
# ------------------------------------------------------------
# Show plots
# ------------------------------------------------------------
plot!(
    p3,
    gamma_list,
    fit_curve,
    lw = 2,
    linestyle = :dash,
    label = "power-law fit (slope = $(round(b, digits=6)))"
)

display(p2)
# Out:
# ┌ Warning: Opening file with JLD2.MmapIO failed, falling back to IOStream
# └ @ JLD2 ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:154
# SystemError: opening file "./data/gamma_scan_B2Wholes.jld2": No such file or directory
#
# Stacktrace:
#   [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#     @ Base ./error.jl:176
#   [2] systemerror
#     @ ./error.jl:176
#   [3] systemerror
#     @ ./error.jl:175 [inlined]
#   [4] open(fname::String; lock::Bool, read::Bool, write::Bool, create::Bool, truncate::Bool, append::Bool)
#     @ Base ./iostream.jl:295
#   [5] open
#     @ ./iostream.jl:277 [inlined]
#   [6] openfile
#     @ ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:144 [inlined]
#   [7] openfile(T::Type, fname::String, wr::Bool, create::Bool, truncate::Bool, fallback::Type)
#     @ JLD2 ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:155
#   [8] jldopen(fname::String, wr::Bool, create::Bool, truncate::Bool, iotype::Type{JLD2.MmapIO}; fallback::Type{IOStream}, compress::Bool, mmaparrays::Bool, typemap::Function, parallel_read::Bool, plain::Bool)
#     @ JLD2 ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:216
#   [9] jldopen
#     @ ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:165 [inlined]
#  [10] #jldopen#23
#     @ ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:286 [inlined]
#  [11] jldopen (repeats 2 times)
#     @ ~/.julia/packages/JLD2/SgtOb/src/JLD2.jl:279 [inlined]
#  [12] jldopen(f::Function, args::String; kws::@Kwargs{})
#     @ JLD2 ~/.julia/packages/JLD2/SgtOb/src/loadsave.jl:2
#  [13] jldopen(f::Function, args::String)
#     @ JLD2 ~/.julia/packages/JLD2/SgtOb/src/loadsave.jl:1
#  [14] macro expansion
#     @ ~/.julia/packages/JLD2/SgtOb/src/loadsave.jl:152 [inlined]
#  [15] top-level scope
#     @ In[3]:4
